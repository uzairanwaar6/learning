# %%
import pandas as pd
import numpy as np
import random
import time
import os
from datetime import datetime
import multiprocessing as mp


def generate_chunk_data_to_file(args):
    chunk_index, chunk_size, seed, price_noise_multiplier, feature_noise_multiplier, data_type, num_classes, output_path, verbose = args

    np.random.seed(seed + chunk_index)
    random.seed(seed + chunk_index)

    def generate_zipcode():
        return random.choice(['90210', '10001', '60614', '94105', '77005', '30303', '98101'])

    def generate_floor_material():
        return random.choice(['Wood', 'Tile', 'Carpet', 'Mixed'])

    def generate_exterior_quality():
        return random.choice(['Poor', 'Fair', 'Good', 'Excellent'])

    def generate_sale_season():
        return random.choice(['Spring', 'Summer', 'Fall', 'Winter'])

    data = {
        'Bedrooms': np.random.randint(1, 6, chunk_size),
        'Bathrooms': np.random.randint(1, 5, chunk_size),
        'TotalArea': np.random.normal(2000, 500, chunk_size).clip(500, 5000),
        'GarageSize': np.random.normal(300, 100, chunk_size).clip(0, 1000),
        'HasPool': np.random.choice([0, 1], chunk_size, p=[0.8, 0.2]),
        'PoolSize': np.random.normal(400, 150, chunk_size).clip(0, 1000),
        'LotSize': np.random.normal(8000, 3000, chunk_size).clip(2000, 20000),
        'HouseAge': np.random.randint(0, 100, chunk_size),
        'RenovatedYear': np.random.choice(list(range(1950, 2025)) + [0], chunk_size),
        'HasFireplace': np.random.choice([0, 1], chunk_size, p=[0.6, 0.4]),
        'FireplaceCount': np.random.randint(0, 4, chunk_size),
        'ZipCode': [generate_zipcode() for _ in range(chunk_size)],
        'SchoolRating': np.random.randint(1, 11, chunk_size),
        'CrimeRate': np.random.normal(3, 1.5, chunk_size).clip(0, 10),
        'NearbyParks': np.random.randint(0, 6, chunk_size),
        'DistanceToDowntown': np.random.normal(10, 5, chunk_size).clip(0, 50),
        'MonthlyHOAFee': np.random.normal(150, 50, chunk_size).clip(0, 1000),
        'ExteriorQuality': [generate_exterior_quality() for _ in range(chunk_size)],
        'FloorMaterial': [generate_floor_material() for _ in range(chunk_size)],
        'SaleSeason': [generate_sale_season() for _ in range(chunk_size)],
        'ListingDuration': np.random.randint(5, 180, chunk_size)
    }

    df = pd.DataFrame(data)

    if feature_noise_multiplier > 0:
        numerical_noise_std = {
            'TotalArea': 50,
            'GarageSize': 20,
            'PoolSize': 30,
            'LotSize': 100,
            'HouseAge': 3,
            'CrimeRate': 0.5,
            'MonthlyHOAFee': 10,
            'DistanceToDowntown': 1,
        }

        for col, std in numerical_noise_std.items():
            df[col] += np.random.normal(0, std * feature_noise_multiplier, chunk_size)

        for col in ['HasPool', 'HasFireplace']:
            flip_mask = np.random.rand(chunk_size) < feature_noise_multiplier
            df.loc[flip_mask, col] = 1 - df.loc[flip_mask, col]

        for col, generator in [('ZipCode', generate_zipcode),
                               ('ExteriorQuality', generate_exterior_quality),
                               ('FloorMaterial', generate_floor_material),
                               ('SaleSeason', generate_sale_season)]:
            mask = np.random.rand(chunk_size) < feature_noise_multiplier
            df.loc[mask, col] = [generator() for _ in range(mask.sum())]

    score = (
        50000 * df['Bedrooms'] +
        40000 * df['Bathrooms'] +
        100 * df['TotalArea'] +
        50 * df['GarageSize'] +
        10000 * df['HasPool'] +
        20 * df['PoolSize'] +
        0.5 * df['LotSize'] -
        1000 * df['HouseAge'] +
        3000 * df['HasFireplace'] +
        2000 * df['FireplaceCount'] +
        5000 * df['SchoolRating'] -
        3000 * df['CrimeRate'] +
        1000 * df['NearbyParks'] -
        800 * df['DistanceToDowntown'] -
        2 * df['MonthlyHOAFee'] -
        100 * df['ListingDuration']
    )

    noisy_score = score + np.random.normal(0, score.std() * price_noise_multiplier, chunk_size)

    if data_type == "linear":
        df["SalePrice"] = noisy_score
    elif data_type == "binary":
        threshold = np.percentile(noisy_score, 60)
        df["WillSell"] = (noisy_score >= threshold).astype(int)
    elif data_type == "multiclass":
        try:
            if num_classes <= 10:
                label_templates = {
                    2: ["Low", "High"],
                    3: ["Low", "Medium", "High"],
                    4: ["Very Low", "Low", "High", "Very High"],
                    5: ["Very Low", "Low", "Medium", "High", "Very High"],
                    6: ["Very Low", "Low", "Mid-Low", "Mid", "Mid-High", "High"],
                    7: ["Very Low", "Low", "Mid-Low", "Mid", "Mid-High", "High", "Very High"],
                    8: ["Extremely Low", "Very Low", "Low", "Mid-Low", "Mid-High", "High", "Very High", "Extremely High"],
                    9: ["Extremely Low", "Very Low", "Low", "Lower-Mid", "Mid", "Upper-Mid", "High", "Very High", "Extremely High"],
                    10: ["Extremely Low", "Very Low", "Low", "Lower-Mid", "Mid-Low", "Mid-High", "Upper-Mid", "High", "Very High", "Extremely High"]
                }
                labels = label_templates[num_classes]
            elif num_classes <= 30:
                labels = [
                    "Extremely Low", "Very Low", "Low", "Lower-Mid", "Below Average",
                    "Slightly Below Average", "Near Average (Low)", "Approaching Average", "Average (Low)", "Average",
                    "Average (High)", "Near Average (High)", "Slightly Above Average", "Above Average", "Moderately High",
                    "High", "Very High", "Extremely High", "Luxury Entry", "Luxury Basic",
                    "Luxury Premium", "Elite Entry", "Elite", "Upper Elite", "Wealthy",
                    "High-End Luxury", "Ultra Luxury", "Prestige Class", "Estate Class", "Super Elite"
                ][:num_classes]
            else:
                labels = [f"Category {i+1}" for i in range(num_classes)]

            df["PriceCategory"] = pd.qcut(noisy_score, q=num_classes, labels=labels, duplicates='drop')
        except Exception as e:
            df["PriceCategory"] = "Unknown"

    os.makedirs(output_path, exist_ok=True)
    chunk_file = os.path.join(output_path, f"chunk_{chunk_index}.csv")
    df.to_csv(chunk_file, index=False)
    if verbose:
        print(f"✅ Chunk {chunk_index} saved: {chunk_file}")
    return chunk_file


def generate_house_pricing_data(
    num_records=1000,
    price_noise_percent=0,
    feature_noise_percent=0,
    data_type="linear",
    num_classes=3,
    output_file="",
    chunk_size=100_000,
    num_workers=1,
    merge_chunks=True,
    delete_chunks=True,
    verbose=True
):
    seed = int(time.time())
    np.random.seed(seed)
    random.seed(seed)

    if not output_file:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file = f"house_data_{data_type}_{num_records}recs_{timestamp}.csv"

    output_dir = os.path.dirname(output_file)
    output_dir = output_dir if output_dir else "."
    chunk_dir = os.path.join(output_dir, f"chunks_{datetime.now().strftime('%Y%m%d_%H%M%S')}")
    os.makedirs(chunk_dir, exist_ok=True)

    num_chunks = (num_records + chunk_size - 1) // chunk_size
    ranges = [
        (i, min(chunk_size, num_records - i * chunk_size), seed,
         price_noise_percent / 100.0, feature_noise_percent / 100.0,
         data_type, num_classes, chunk_dir, verbose)
        for i in range(num_chunks)
    ]

    if verbose:
        print(f"🔧 Generating {num_records} records in {num_chunks} chunks...")

    if num_workers == 1 or num_chunks == 1:
        chunk_files = [generate_chunk_data_to_file(r) for r in ranges]
    else:
        with mp.Pool(num_workers) as pool:
            chunk_files = pool.map(generate_chunk_data_to_file, ranges)

    if verbose:
        print(f"✅ {len(chunk_files)} chunk files created in: {chunk_dir}")

    if merge_chunks:
        if verbose:
            print("🔄 Merging chunk files into a single CSV...")
        combined_df = pd.concat((pd.read_csv(f) for f in sorted(chunk_files)), ignore_index=True)
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        combined_df.to_csv(output_file, index=False)
        if verbose:
            print(f"✅ Merged file saved as: {output_file}")

        if delete_chunks:
            if verbose:
                print("🗑️ Deleting chunk files...")
            for f in chunk_files:
                try:
                    os.remove(f)
                except Exception as e:
                    if verbose:
                        print(f"⚠️ Failed to delete {f}: {e}")
            try:
                os.rmdir(chunk_dir)
                if verbose:
                    print(f"🧹 Deleted chunk directory: {chunk_dir}")
            except Exception as e:
                if verbose:
                    print(f"⚠️ Failed to delete chunk directory {chunk_dir}: {e}")
    else:
        if verbose:
            print("ℹ️ Skipping merge. Use `merge_chunks=True` to enable merging.")

# %%
def human_format(number, precision=1):
    """
    Convert a number into a human-readable format:
    1234 -> 1.2k
    1000000 -> 1m
    850 -> 850
    """
    suffixes = ['', 'k', 'm', 'b', 't']
    num = float(number)
    magnitude = 0

    while abs(num) >= 1000 and magnitude < len(suffixes) - 1:
        magnitude += 1
        num /= 1000.0

    if magnitude == 0:
        return str(int(number))  # show full number for values < 1000

    formatted = f"{num:.{precision}f}".rstrip('0').rstrip('.')
    return f"{formatted}{suffixes[magnitude]}"

# %%
t_noise = 0
f_noise = 0
records = 10000000
chunk_size = records // 100
num_classes=5



# Linear regression
# filePath = "../data/NuralNetwork/linear/house_pricing_linear_"+str(human_format(records))+"_TN_"+str(t_noise)+"_FN_"+str(f_noise)+".csv"
# generate_house_pricing_data(
#     num_records=records,
#     price_noise_percent=t_noise,
#     feature_noise_percent=f_noise,
#     output_file=filePath
# )



# # Binary classification
# filePath = "../data/NuralNetwork/binary/house_pricing_binary_"+str(human_format(records))+"_TN_"+str(t_noise)+"_FN_"+str(f_noise)+".csv"
# generate_house_pricing_data(
#     num_records=records,
#     price_noise_percent=t_noise,
#     feature_noise_percent=f_noise,
#     output_file=filePath, 
#     data_type="binary")

# # Multi-class 
filePath = "../data/NuralNetwork/multi-class/house_pricing_ multiclass_"+str(num_classes)+"_"+str(human_format(records))+"_TN_"+str(t_noise)+"_FN_"+str(f_noise)+".csv"
generate_house_pricing_data(    
    num_records=records,
    price_noise_percent=t_noise,
    feature_noise_percent=f_noise,
    output_file=filePath, 
    data_type="multiclass", 
    num_classes=num_classes,
    chunk_size=chunk_size)
# Out:
# 🔧 Generating 10000000 records in 100 chunks...
# ✅ Chunk 0 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_0.csv
# ✅ Chunk 1 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_1.csv
# ✅ Chunk 2 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_2.csv
# ✅ Chunk 3 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_3.csv
# ✅ Chunk 4 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_4.csv
# ✅ Chunk 5 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_5.csv
# ✅ Chunk 6 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_6.csv
# ✅ Chunk 7 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_7.csv
# ✅ Chunk 8 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_8.csv
# ✅ Chunk 9 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_9.csv
# ✅ Chunk 10 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_10.csv
# ✅ Chunk 11 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_11.csv
# ✅ Chunk 12 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_12.csv
# ✅ Chunk 13 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_13.csv
# ✅ Chunk 14 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_14.csv
# ✅ Chunk 15 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_15.csv
# ✅ Chunk 16 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_16.csv
# ✅ Chunk 17 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_17.csv
# ✅ Chunk 18 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_18.csv
# ✅ Chunk 19 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_19.csv
# ✅ Chunk 20 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_20.csv
# ✅ Chunk 21 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_21.csv
# ✅ Chunk 22 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_22.csv
# ✅ Chunk 23 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_23.csv
# ✅ Chunk 24 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_24.csv
# ✅ Chunk 25 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_25.csv
# ✅ Chunk 26 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_26.csv
# ✅ Chunk 27 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_27.csv
# ✅ Chunk 28 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_28.csv
# ✅ Chunk 29 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_29.csv
# ✅ Chunk 30 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_30.csv
# ✅ Chunk 31 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_31.csv
# ✅ Chunk 32 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_32.csv
# ✅ Chunk 33 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_33.csv
# ✅ Chunk 34 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_34.csv
# ✅ Chunk 35 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_35.csv
# ✅ Chunk 36 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_36.csv
# ✅ Chunk 37 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_37.csv
# ✅ Chunk 38 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_38.csv
# ✅ Chunk 39 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_39.csv
# ✅ Chunk 40 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_40.csv
# ✅ Chunk 41 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_41.csv
# ✅ Chunk 42 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_42.csv
# ✅ Chunk 43 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_43.csv
# ✅ Chunk 44 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_44.csv
# ✅ Chunk 45 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_45.csv
# ✅ Chunk 46 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_46.csv
# ✅ Chunk 47 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_47.csv
# ✅ Chunk 48 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_48.csv
# ✅ Chunk 49 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_49.csv
# ✅ Chunk 50 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_50.csv
# ✅ Chunk 51 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_51.csv
# ✅ Chunk 52 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_52.csv
# ✅ Chunk 53 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_53.csv
# ✅ Chunk 54 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_54.csv
# ✅ Chunk 55 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_55.csv
# ✅ Chunk 56 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_56.csv
# ✅ Chunk 57 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_57.csv
# ✅ Chunk 58 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_58.csv
# ✅ Chunk 59 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_59.csv
# ✅ Chunk 60 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_60.csv
# ✅ Chunk 61 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_61.csv
# ✅ Chunk 62 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_62.csv
# ✅ Chunk 63 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_63.csv
# ✅ Chunk 64 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_64.csv
# ✅ Chunk 65 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_65.csv
# ✅ Chunk 66 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_66.csv
# ✅ Chunk 67 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_67.csv
# ✅ Chunk 68 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_68.csv
# ✅ Chunk 69 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_69.csv
# ✅ Chunk 70 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_70.csv
# ✅ Chunk 71 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_71.csv
# ✅ Chunk 72 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_72.csv
# ✅ Chunk 73 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_73.csv
# ✅ Chunk 74 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_74.csv
# ✅ Chunk 75 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_75.csv
# ✅ Chunk 76 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_76.csv
# ✅ Chunk 77 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_77.csv
# ✅ Chunk 78 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_78.csv
# ✅ Chunk 79 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_79.csv
# ✅ Chunk 80 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_80.csv
# ✅ Chunk 81 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_81.csv
# ✅ Chunk 82 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_82.csv
# ✅ Chunk 83 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_83.csv
# ✅ Chunk 84 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_84.csv
# ✅ Chunk 85 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_85.csv
# ✅ Chunk 86 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_86.csv
# ✅ Chunk 87 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_87.csv
# ✅ Chunk 88 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_88.csv
# ✅ Chunk 89 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_89.csv
# ✅ Chunk 90 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_90.csv
# ✅ Chunk 91 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_91.csv
# ✅ Chunk 92 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_92.csv
# ✅ Chunk 93 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_93.csv
# ✅ Chunk 94 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_94.csv
# ✅ Chunk 95 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_95.csv
# ✅ Chunk 96 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_96.csv
# ✅ Chunk 97 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_97.csv
# ✅ Chunk 98 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_98.csv
# ✅ Chunk 99 saved: ../data/NuralNetwork/multi-class\chunks_20250707_172207\chunk_99.csv
# ✅ 100 chunk files created in: ../data/NuralNetwork/multi-class\chunks_20250707_172207
# 🔄 Merging chunk files into a single CSV...
# ✅ Merged file saved as: ../data/NuralNetwork/multi-class/house_pricing_ multiclass_5_10m_TN_0_FN_0.csv
# 🗑️ Deleting chunk files...
# 🧹 Deleted chunk directory: ../data/NuralNetwork/multi-class\chunks_20250707_172207
